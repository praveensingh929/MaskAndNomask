# %%
# clone repository for deepsort with yolov4
# !git clone https://github.com/theAIGuysCode/yolov4-deepsort
# Out:
# Cloning into 'yolov4-deepsort'...

# %%
# step into the yolov4-deepsort folder
# %cd yolov4-deepsort/
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov4-deepsort/'
# C:\Users\prvns\yolov4-deepsort

# %%
# Convert darknet weights to tensorflow model

# !python save_model.py --model yolov4
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 416, 416, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 416, 416, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  tf.math.softplus (TFOpLambda)  (None, 416, 416, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  tf.math.tanh (TFOpLambda)      (None, 416, 416, 32  0           ['tf.math.softplus[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 416, 416, 32  0           ['batch_normalization[0][0]',
#                                 )                                 'tf.math.tanh[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 417, 417, 32  0          ['tf.math.multiply[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 208, 208, 64  18432       ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 208, 208, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_1 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_1[0][0]']
#  )                              )
#
#  tf.math.tanh_1 (TFOpLambda)    (None, 208, 208, 64  0           ['tf.math.softplus_1[0][0]']
#                                 )
#
#  tf.math.multiply_1 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_1[0][0]',
#  )                              )                                 'tf.math.tanh_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 208, 208, 64  4096        ['tf.math.multiply_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 208, 208, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_3 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_3[0][0]']
#  )                              )
#
#  tf.math.tanh_3 (TFOpLambda)    (None, 208, 208, 64  0           ['tf.math.softplus_3[0][0]']
#                                 )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_3[0][0]',
#  )                              )                                 'tf.math.tanh_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 208, 208, 32  2048        ['tf.math.multiply_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 208, 208, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_4 (TFOpLambda  (None, 208, 208, 32  0          ['batch_normalization_4[0][0]']
#  )                              )
#
#  tf.math.tanh_4 (TFOpLambda)    (None, 208, 208, 32  0           ['tf.math.softplus_4[0][0]']
#                                 )
#
#  tf.math.multiply_4 (TFOpLambda  (None, 208, 208, 32  0          ['batch_normalization_4[0][0]',
#  )                              )                                 'tf.math.tanh_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 208, 208, 64  18432       ['tf.math.multiply_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 208, 208, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_5 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_5[0][0]']
#  )                              )
#
#  tf.math.tanh_5 (TFOpLambda)    (None, 208, 208, 64  0           ['tf.math.softplus_5[0][0]']
#                                 )
#
#  tf.math.multiply_5 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_5[0][0]',
#  )                              )                                 'tf.math.tanh_5[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 208, 208, 64  0          ['tf.math.multiply_3[0][0]',
#  da)                            )                                 'tf.math.multiply_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 208, 208, 64  4096        ['tf.__operators__.add[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 208, 208, 64  4096        ['tf.math.multiply_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 208, 208, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 208, 208, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_6 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_6[0][0]']
#  )                              )
#
#  tf.math.softplus_2 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_2[0][0]']
#  )                              )
#
#  tf.math.tanh_6 (TFOpLambda)    (None, 208, 208, 64  0           ['tf.math.softplus_6[0][0]']
#                                 )
#
#  tf.math.tanh_2 (TFOpLambda)    (None, 208, 208, 64  0           ['tf.math.softplus_2[0][0]']
#                                 )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_6[0][0]',
#  )                              )                                 'tf.math.tanh_6[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_2[0][0]',
#  )                              )                                 'tf.math.tanh_2[0][0]']
#
#  tf.concat (TFOpLambda)         (None, 208, 208, 12  0           ['tf.math.multiply_6[0][0]',
#                                 8)                                'tf.math.multiply_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 208, 208, 64  8192        ['tf.concat[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 208, 208, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_7 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_7[0][0]']
#  )                              )
#
#  tf.math.tanh_7 (TFOpLambda)    (None, 208, 208, 64  0           ['tf.math.softplus_7[0][0]']
#                                 )
#
#  tf.math.multiply_7 (TFOpLambda  (None, 208, 208, 64  0          ['batch_normalization_7[0][0]',
#  )                              )                                 'tf.math.tanh_7[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 209, 209, 64  0          ['tf.math.multiply_7[0][0]']
#  D)                             )
#
#  conv2d_8 (Conv2D)              (None, 104, 104, 12  73728       ['zero_padding2d_1[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 104, 104, 12  512        ['conv2d_8[0][0]']
#  rmalization)                   8)
#
#  tf.math.softplus_8 (TFOpLambda  (None, 104, 104, 12  0          ['batch_normalization_8[0][0]']
#  )                              8)
#
#  tf.math.tanh_8 (TFOpLambda)    (None, 104, 104, 12  0           ['tf.math.softplus_8[0][0]']
#                                 8)
#
#  tf.math.multiply_8 (TFOpLambda  (None, 104, 104, 12  0          ['batch_normalization_8[0][0]',
#  )                              8)                                'tf.math.tanh_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 104, 104, 64  8192        ['tf.math.multiply_8[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 104, 104, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
# 2022-11-20 18:24:07.950399: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-11-20 18:24:07.950498: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-20 18:24:12.510534: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-11-20 18:24:12.538129: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-20 18:24:12.545939: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: LAPTOP-1NB0LHRB
# 2022-11-20 18:24:12.546185: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: LAPTOP-1NB0LHRB
# 2022-11-20 18:24:12.838350: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# W1120 18:24:26.467809  2120 saving_utils.py:359] Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# W1120 18:25:10.713340  2120 save.py:269] Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 110). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./checkpoints/yolov4-416\assets
# I1120 18:25:33.034914  2120 builder_impl.py:779] Assets written to: ./checkpoints/yolov4-416\assets
#  tf.math.softplus_10 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_10[0][0]']
#  a)                             )
#
#  tf.math.tanh_10 (TFOpLambda)   (None, 104, 104, 64  0           ['tf.math.softplus_10[0][0]']
#                                 )
#
#  tf.math.multiply_10 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_10[0][0]',
#  a)                             )                                 'tf.math.tanh_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 104, 104, 64  4096        ['tf.math.multiply_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 104, 104, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  tf.math.softplus_11 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_11[0][0]']
#  a)                             )
#
#  tf.math.tanh_11 (TFOpLambda)   (None, 104, 104, 64  0           ['tf.math.softplus_11[0][0]']
#                                 )
#
#  tf.math.multiply_11 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_11[0][0]',
#  a)                             )                                 'tf.math.tanh_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 104, 104, 64  36864       ['tf.math.multiply_11[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 104, 104, 64  256        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  tf.math.softplus_12 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_12[0][0]']
#  a)                             )
#
#  tf.math.tanh_12 (TFOpLambda)   (None, 104, 104, 64  0           ['tf.math.softplus_12[0][0]']
#                                 )
#
#  tf.math.multiply_12 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_12[0][0]',
#  a)                             )                                 'tf.math.tanh_12[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 104, 104, 64  0          ['tf.math.multiply_10[0][0]',
#  mbda)                          )                                 'tf.math.multiply_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 104, 104, 64  4096        ['tf.__operators__.add_1[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 104, 104, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  tf.math.softplus_13 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_13[0][0]']
#  a)                             )
#
#  tf.math.tanh_13 (TFOpLambda)   (None, 104, 104, 64  0           ['tf.math.softplus_13[0][0]']
#                                 )
#
#  tf.math.multiply_13 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_13[0][0]',
#  a)                             )                                 'tf.math.tanh_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 104, 104, 64  36864       ['tf.math.multiply_13[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 104, 104, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  tf.math.softplus_14 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_14[0][0]']
#  a)                             )
#
#  tf.math.tanh_14 (TFOpLambda)   (None, 104, 104, 64  0           ['tf.math.softplus_14[0][0]']
#                                 )
#
#  tf.math.multiply_14 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_14[0][0]',
#  a)                             )                                 'tf.math.tanh_14[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 104, 104, 64  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                          )                                 'tf.math.multiply_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 104, 104, 64  4096        ['tf.__operators__.add_2[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 104, 104, 64  8192        ['tf.math.multiply_8[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 104, 104, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  batch_normalization_9 (BatchNo  (None, 104, 104, 64  256        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  tf.math.softplus_15 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_15[0][0]']
#  a)                             )
#
#  tf.math.softplus_9 (TFOpLambda  (None, 104, 104, 64  0          ['batch_normalization_9[0][0]']
#  )                              )
#
#  tf.math.tanh_15 (TFOpLambda)   (None, 104, 104, 64  0           ['tf.math.softplus_15[0][0]']
#                                 )
#
#  tf.math.tanh_9 (TFOpLambda)    (None, 104, 104, 64  0           ['tf.math.softplus_9[0][0]']
#                                 )
#
#  tf.math.multiply_15 (TFOpLambd  (None, 104, 104, 64  0          ['batch_normalization_15[0][0]',
#  a)                             )                                 'tf.math.tanh_15[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 104, 104, 64  0          ['batch_normalization_9[0][0]',
#  )                              )                                 'tf.math.tanh_9[0][0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 104, 104, 12  0           ['tf.math.multiply_15[0][0]',
#                                 8)                                'tf.math.multiply_9[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 104, 104, 12  16384       ['tf.concat_1[0][0]']
#                                 8)
#
#  batch_normalization_16 (BatchN  (None, 104, 104, 12  512        ['conv2d_16[0][0]']
#  ormalization)                  8)
#
#  tf.math.softplus_16 (TFOpLambd  (None, 104, 104, 12  0          ['batch_normalization_16[0][0]']
#  a)                             8)
#
#  tf.math.tanh_16 (TFOpLambda)   (None, 104, 104, 12  0           ['tf.math.softplus_16[0][0]']
#                                 8)
#
#  tf.math.multiply_16 (TFOpLambd  (None, 104, 104, 12  0          ['batch_normalization_16[0][0]',
#  a)                             8)                                'tf.math.tanh_16[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 105, 105, 12  0          ['tf.math.multiply_16[0][0]']
#  D)                             8)
#
#  conv2d_17 (Conv2D)             (None, 52, 52, 256)  294912      ['zero_padding2d_2[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 52, 52, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  tf.math.softplus_17 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_17[0][0]']
#  a)
#
#  tf.math.tanh_17 (TFOpLambda)   (None, 52, 52, 256)  0           ['tf.math.softplus_17[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 52, 52, 256)  0          ['batch_normalization_17[0][0]',
#  a)                                                               'tf.math.tanh_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 52, 52, 128)  32768       ['tf.math.multiply_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 52, 52, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  tf.math.softplus_19 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_19[0][0]']
#  a)
#
#  tf.math.tanh_19 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_19[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_19[0][0]',
#  a)                                                               'tf.math.tanh_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 52, 52, 128)  16384       ['tf.math.multiply_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 52, 52, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  tf.math.softplus_20 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_20[0][0]']
#  a)
#
#  tf.math.tanh_20 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_20[0][0]']
#
#  tf.math.multiply_20 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_20[0][0]',
#  a)                                                               'tf.math.tanh_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 52, 52, 128)  147456      ['tf.math.multiply_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 52, 52, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  tf.math.softplus_21 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_21[0][0]']
#  a)
#
#  tf.math.tanh_21 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_21[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_21[0][0]',
#  a)                                                               'tf.math.tanh_21[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 52, 52, 128)  0          ['tf.math.multiply_19[0][0]',
#  mbda)                                                            'tf.math.multiply_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 52, 52, 128)  16384       ['tf.__operators__.add_3[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 52, 52, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  tf.math.softplus_22 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_22[0][0]']
#  a)
#
#  tf.math.tanh_22 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_22[0][0]',
#  a)                                                               'tf.math.tanh_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 52, 52, 128)  147456      ['tf.math.multiply_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 52, 52, 128)  512        ['conv2d_23[0][0]']
#  ormalization)
#
#  tf.math.softplus_23 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_23[0][0]']
#  a)
#
#  tf.math.tanh_23 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_23[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_23[0][0]',
#  a)                                                               'tf.math.tanh_23[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 52, 52, 128)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'tf.math.multiply_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 52, 52, 128)  16384       ['tf.__operators__.add_4[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 52, 52, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  tf.math.softplus_24 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_24[0][0]']
#  a)
#
#  tf.math.tanh_24 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_24[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_24[0][0]',
#  a)                                                               'tf.math.tanh_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 52, 52, 128)  147456      ['tf.math.multiply_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 52, 52, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  tf.math.softplus_25 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_25[0][0]']
#  a)
#
#  tf.math.tanh_25 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_25[0][0]',
#  a)                                                               'tf.math.tanh_25[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 52, 52, 128)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'tf.math.multiply_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 52, 52, 128)  16384       ['tf.__operators__.add_5[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 52, 52, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  tf.math.softplus_26 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_26[0][0]']
#  a)
#
#  tf.math.tanh_26 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_26[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_26[0][0]',
#  a)                                                               'tf.math.tanh_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 52, 52, 128)  147456      ['tf.math.multiply_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 52, 52, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  tf.math.softplus_27 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_27[0][0]']
#  a)
#
#  tf.math.tanh_27 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_27[0][0]',
#  a)                                                               'tf.math.tanh_27[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 52, 52, 128)  0          ['tf.__operators__.add_5[0][0]',
#  mbda)                                                            'tf.math.multiply_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 52, 52, 128)  16384       ['tf.__operators__.add_6[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 52, 52, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  tf.math.softplus_28 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_28[0][0]']
#  a)
#
#  tf.math.tanh_28 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_28[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_28[0][0]',
#  a)                                                               'tf.math.tanh_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 52, 52, 128)  147456      ['tf.math.multiply_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 52, 52, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  tf.math.softplus_29 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_29[0][0]']
#  a)
#
#  tf.math.tanh_29 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_29[0][0]']
#
#  tf.math.multiply_29 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_29[0][0]',
#  a)                                                               'tf.math.tanh_29[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 52, 52, 128)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'tf.math.multiply_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 52, 52, 128)  16384       ['tf.__operators__.add_7[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 52, 52, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  tf.math.softplus_30 (TFOpLambd  (None, 52, 52, 128)  0          ['batch_normalization_30[0][0]']
#  a)
#
#  tf.math.tanh_30 (TFOpLambda)   (None, 52, 52, 128)  0           ['tf.math.softplus_30[0][0]']
# ...
#
#  tf.math.multiply_74 (TFOpLambd  (None, 52, 52, 3, 2  0          ['tf.math.exp[0][0]']
#  a)                             )
#
#  tf.math.multiply_77 (TFOpLambd  (None, 26, 26, 3, 2  0          ['tf.__operators__.add_24[0][0]']
#  a)                             )
#
#  tf.math.multiply_78 (TFOpLambd  (None, 26, 26, 3, 2  0          ['tf.math.exp_1[0][0]']
#  a)                             )
#
#  tf.math.multiply_81 (TFOpLambd  (None, 13, 13, 3, 2  0          ['tf.__operators__.add_25[0][0]']
#  a)                             )
#
#  tf.math.multiply_82 (TFOpLambd  (None, 13, 13, 3, 2  0          ['tf.math.exp_2[0][0]']
#  a)                             )
#
#  tf.reshape_1 (TFOpLambda)      (None, None, 2)      0           ['tf.math.multiply_75[0][0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.reshape_4 (TFOpLambda)      (None, None, 2)      0           ['tf.math.multiply_79[0][0]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.reshape_7 (TFOpLambda)      (None, None, 2)      0           ['tf.math.multiply_83[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.concat_10 (TFOpLambda)      (None, 52, 52, 3, 4  0           ['tf.math.multiply_73[0][0]',
#                                 )                                 'tf.math.multiply_74[0][0]']
#
#  tf.concat_11 (TFOpLambda)      (None, 26, 26, 3, 4  0           ['tf.math.multiply_77[0][0]',
#                                 )                                 'tf.math.multiply_78[0][0]']
#
#  tf.concat_12 (TFOpLambda)      (None, 13, 13, 3, 4  0           ['tf.math.multiply_81[0][0]',
#                                 )                                 'tf.math.multiply_82[0][0]']
#
#  tf.concat_14 (TFOpLambda)      (None, None, 2)      0           ['tf.reshape_1[0][0]',
#                                                                   'tf.reshape_4[0][0]',
#                                                                   'tf.reshape_7[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, None, 4)      0           ['tf.concat_10[0][0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.reshape_5 (TFOpLambda)      (None, None, 4)      0           ['tf.concat_11[0][0]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.reshape_8 (TFOpLambda)      (None, None, 4)      0           ['tf.concat_12[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.math.reduce_max (TFOpLambda  (None, None)        0           ['tf.concat_14[0][0]']
#  )
#
#  tf.concat_13 (TFOpLambda)      (None, None, 4)      0           ['tf.reshape_2[0][0]',
#                                                                   'tf.reshape_5[0][0]',
#                                                                   'tf.reshape_8[0][0]']
#
#  tf.math.greater_equal (TFOpLam  (None, None)        0           ['tf.math.reduce_max[0][0]']
#  bda)
#
#  tf.compat.v1.boolean_mask (Sli  (None, 4)           0           ['tf.concat_13[0][0]',
#  cingOpLambda)                                                    'tf.math.greater_equal[0][0]']
#
#  tf.compat.v1.shape_3 (TFOpLamb  (3,)                0           ['tf.concat_14[0][0]']
#  da)
#
#  tf.compat.v1.shape_4 (TFOpLamb  (2,)                0           ['tf.compat.v1.boolean_mask[0][0]
#  da)                                                             ']
#
#  tf.__operators__.getitem_3 (Sl  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_4 (Sl  ()                  0           ['tf.compat.v1.shape_4[0][0]']
#  icingOpLambda)
#
#  tf.reshape_9 (TFOpLambda)      (None, None, 4)      0           ['tf.compat.v1.boolean_mask[0][0]
#                                                                  ',
#                                                                   'tf.__operators__.getitem_3[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  tf.split_3 (TFOpLambda)        [(None, None, 2),    0           ['tf.reshape_9[0][0]']
#                                  (None, None, 2)]
#
#  tf.__operators__.getitem_8 (Sl  (None, None, 2)     0           ['tf.split_3[0][1]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, None, 2)     0           ['tf.split_3[0][0]']
#  icingOpLambda)
#
#  tf.math.truediv (TFOpLambda)   (None, None, 2)      0           ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, None, 2)     0           ['tf.__operators__.getitem_8[0][0
#                                                                  ]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, None, 2)     0           ['tf.__operators__.getitem_7[0][0
#  )                                                               ]',
#                                                                   'tf.math.truediv[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, None, 2)     0           ['tf.__operators__.getitem_7[0][0
#  ambda)                                                          ]',
#                                                                   'tf.math.truediv_2[0][0]']
#
#  tf.compat.v1.boolean_mask_1 (S  (None, 2)           0           ['tf.concat_14[0][0]',
#  licingOpLambda)                                                  'tf.math.greater_equal[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, None, 2)     0           ['tf.math.subtract_3[0][0]']
#
#  tf.math.truediv_3 (TFOpLambda)  (None, None, 2)     0           ['tf.__operators__.add_26[0][0]']
#
#  tf.compat.v1.shape_5 (TFOpLamb  (3,)                0           ['tf.concat_14[0][0]']
#  da)
#
#  tf.compat.v1.shape_6 (TFOpLamb  (2,)                0           ['tf.compat.v1.boolean_mask_1[0][
#  da)                                                             0]']
#
#  tf.__operators__.getitem_9 (Sl  (None, None, 1)     0           ['tf.math.truediv_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_10 (S  (None, None, 1)     0           ['tf.math.truediv_1[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None, None, 1)     0           ['tf.math.truediv_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_12 (S  (None, None, 1)     0           ['tf.math.truediv_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  ()                  0           ['tf.compat.v1.shape_5[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_6 (Sl  ()                  0           ['tf.compat.v1.shape_6[0][0]']
#  icingOpLambda)
#
#  tf.concat_15 (TFOpLambda)      (None, None, 4)      0           ['tf.__operators__.getitem_9[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_10[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_11[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_12[0][
#                                                                  0]']
#
#  tf.reshape_10 (TFOpLambda)     (None, None, 2)      0           ['tf.compat.v1.boolean_mask_1[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_6[0][0
#                                                                  ]']
#
#  tf.concat_16 (TFOpLambda)      (None, None, 6)      0           ['tf.concat_15[0][0]',
#                                                                   'tf.reshape_10[0][0]']
#
# ==================================================================================================
# Total params: 64,009,375
# Trainable params: 63,943,071
# Non-trainable params: 66,304
# __________________________________________________________________________________________________

# %%
# run DeepSort with YOLOv4 Object Detections as backbone (enable --info flag to see info about tracked objects)
# !python object_tracker.py --video ./data/video/main.mp4 --output ./outputs/firstTry.avi --model yolov4 --dont_show --info
# Out:
# Frame #:  1
# FPS: 0.20
# Frame #:  2
# FPS: 1.21
# Frame #:  3
# FPS: 1.25
# Frame #:  4
# FPS: 1.25
# Frame #:  5
# FPS: 1.28
# Frame #:  6
# FPS: 1.28
# Frame #:  7
# FPS: 1.25
# Frame #:  8
# FPS: 1.25
# Frame #:  9
# FPS: 1.25
# Frame #:  10
# FPS: 1.28
# Frame #:  11
# FPS: 1.28
# Frame #:  12
# FPS: 1.28
# Frame #:  13
# FPS: 1.25
# Frame #:  14
# FPS: 1.25
# Frame #:  15
# FPS: 1.28
# Frame #:  16
# FPS: 1.28
# Frame #:  17
# FPS: 1.28
# Frame #:  18
# FPS: 1.25
# Frame #:  19
# FPS: 1.28
# Frame #:  20
# FPS: 1.28
# Frame #:  21
# FPS: 1.28
# Frame #:  22
# FPS: 1.28
# Frame #:  23
# FPS: 1.28
# Frame #:  24
# FPS: 1.21
# Frame #:  25
# FPS: 1.28
# Frame #:  26
# FPS: 1.25
# Frame #:  27
# FPS: 1.25
# Frame #:  28
# FPS: 1.25
# Frame #:  29
# FPS: 1.25
# Frame #:  30
# FPS: 1.28
# Frame #:  31
# FPS: 1.25
# Frame #:  32
# FPS: 1.28
# Frame #:  33
# FPS: 1.28
# Frame #:  34
# FPS: 1.23
# Frame #:  35
# FPS: 1.18
# Frame #:  36
# FPS: 1.06
# Frame #:  37
# FPS: 1.22
# Frame #:  38
# FPS: 1.15
# Frame #:  39
# FPS: 1.21
# Frame #:  40
# FPS: 1.21
# Frame #:  41
# FPS: 1.14
# Frame #:  42
# FPS: 1.13
# Frame #:  43
# FPS: 1.18
# Frame #:  44
# FPS: 1.13
# Frame #:  45
# FPS: 1.12
# Frame #:  46
# FPS: 1.05
# Frame #:  47
# FPS: 1.16
# Frame #:  48
# FPS: 1.21
# Frame #:  49
# FPS: 1.10
# Frame #:  50
# FPS: 1.19
# Frame #:  51
# FPS: 1.13
# Frame #:  52
# FPS: 1.12
# Frame #:  53
# FPS: 1.08
# Frame #:  54
# FPS: 1.04
# Frame #:  55
# FPS: 1.05
# Frame #:  56
# FPS: 1.03
